# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/raianars_set_2020/blob/master/scrap_google_trends_sept_05_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytrends

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %%
# https://towardsdatascience.com/google-trends-api-for-python-a84bc25db88f

# %%
pytrend.build_payload(kw_list=['python','r language','machine learning','artificial intelligence'])
# Interest by Region
df = pytrend.interest_by_region()
df.head(10)
# Out:
#                    python  ...  artificial intelligence
# geoName                    ...
# Afghanistan             0  ...                        0
# Albania                 0  ...                        0
# Algeria                 0  ...                        0
# American Samoa          0  ...                        0
# Andorra                 0  ...                        0
# Angola                  0  ...                        0
# Anguilla                0  ...                        0
# Antarctica              0  ...                        0
# Antigua & Barbuda       0  ...                        0
# Argentina              93  ...                        1
#
# [10 rows x 4 columns]

# %%
df.reset_index().plot(x='geoName', y='python', figsize=(120, 10), kind ='bar')

# %%
df.reset_index().plot(x='geoName', y='r language', figsize=(120, 10), kind ='bar')

# %%
# Get Google Hot Trends data
df = pytrend.trending_searches(pn='brazil')
df.head()
# Out:
#                         0
# 0    Flamengo x Fortaleza
# 1           Jogos android
# 2                   CBLoL
# 3       José Carlos Lippi
# 4  Vila Nova x Santa Cruz

# %%
# Related Queries, returns a dictionary of dataframes
pytrend.build_payload(kw_list=['python'])
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                 query  value
# 0          for python    100
# 1         python list     92
# 2       python string     75
# 3         python with     64
# 4           if python     43
# 5      python install     41
# 6     python function     35
# 7         python code     35
# 8        monty python     35
# 9      list in python     35
# 10       array python     32
# 11       python print     30
# 12      pandas python     29
# 13    download python     27
# 14  python dictionary     27
# 15        python find     24
# 16    python tutorial     23
# 17      python import     23
# 18         python set     22
# 19        ball python     22
# 20        python loop     21
# 21              numpy     21
# 22       python class     21
# 23               json     20
# 24     what is python     20, 'rising':                                     query  value
# 0                              tensorflow  38900
# 1                        jupyter notebook  12000
# ...

# %%
# Related Queries, returns a dictionary of dataframes
pytrend.build_payload(kw_list=['python applications'])
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                                                query  value
# 0                             applications of python    100
# 1                                 python programming     50
# 2                                     what is python     33
# 3                                    python tutorial     18
# 4                       python applications examples     18
# 5                     applications written in python      9
# 6                                              udemy      3
# 7                                 keras applications      3
# 8               core python applications programming      3
# 9  introduction to python programming and develop...      2, 'rising':                           query  value
# 0                         udemy  41050
# 1            keras applications  39700
# 2                what is python    190
# 3  python applications examples    140
# 4        applications of python    130}])

# %%
# Related Queries, returns a dictionary of dataframes
pytrend.build_payload(kw_list=['python udemy'])
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                         query  value
# 0         python udemy course    100
# 1               python course     99
# 2           udemy python free     74
# 3             learning python     52
# 4               udemy courses     50
# 5        udemy python courses     49
# 6             python download     49
# 7                learn python     45
# 8          learn python udemy     43
# 9             python tutorial     39
# 10         python programming     37
# 11         udemy data science     30
# 12     udemy machine learning     30
# 13      udemy python bootcamp     29
# 14  udemy python data science     28
# 15   udemy python course free     27
# 16   best udemy python course     24
# 17            coursera python     23
# 18         best python course     23
# 19                   coursera     21
# 20         udemy free courses     20
# 21                     django     19
# 22               udemy coupon     18
# 23            python language     17
# ...

# %%
# Related Queries, returns a dictionary of dataframes
pytrend.build_payload(kw_list=['hotmart python'])
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top': None, 'rising': None}])

# %%
# Related Queries, returns a dictionary of dataframes
pytrend.build_payload(kw_list=['python',' udemy'])
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                 query  value
# 0          for python    100
# 1         python list     92
# 2       python string     75
# 3         python with     64
# 4           if python     43
# 5      python install     41
# 6     python function     35
# 7         python code     35
# 8        monty python     35
# 9      list in python     35
# 10       array python     32
# 11       python print     30
# 12      pandas python     29
# 13    download python     27
# 14  python dictionary     27
# 15        python find     24
# 16    python tutorial     23
# 17      python import     23
# 18         python set     22
# 19        ball python     22
# 20        python loop     21
# 21              numpy     21
# 22       python class     21
# 23               json     20
# 24     what is python     20, 'rising':                                     query  value
# 0                              tensorflow  38900
# 1                        jupyter notebook  12000
# ...
